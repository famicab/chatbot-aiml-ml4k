# %% [markdown]
# Import response

# %%
# %pip install response

# %% [markdown]
# Copiamos el codigo de MLK

# %%
import requests

# This function will pass your text to the machine learning model
# and return the top result with the highest confidence
def classify(text):
    key = "cd419ec0-749d-11ec-9ed4-a70226fed41e14d9ed64-3645-4a5a-843b-88b9307dc2e3"
    url = "https://machinelearningforkids.co.uk/api/scratch/"+ key + "/classify"

    response = requests.get(url, params={ "data" : text })

    if response.ok:
        responseData = response.json()
        topMatch = responseData[0]
        return topMatch
    else:
        response.raise_for_status()

# %% [markdown]
# Funcionamiento del chatbot

# %%
import random

def answer_question():
    question = input(">")
    answer = classify(question)
    answerclass = answer["class_name"]
    confidence = answer["confidence"]
    # print(answerclass + " " + str(confidence))
    if confidence > 60:
        if answerclass == "Lineas":
            print ("Actualmente tengo información sobre las lineas 1, 2, 3, 5 y 6. \nLas demás se añadirán en funciones futuras. ¿Sobre cual de ellas quieres información?")
        elif answerclass == "Titulos":
            print ("""Puedo darte información sobre los siguientes títulos:
                   \nBillete univiaje
                   \nTarjeta multiviaje
                   \nTarjeta turística
                   \nTarjeta 30 días
                   \nTarjeta anual
                   \nTarjeta anual
                   \nTarjeta estudiante
                   \n¿Quieres información sobre alguno?""")
        elif answerclass == "Linea_1":
            print ("""Línea 1. Plg. Norte H. Virgen del Rocio
            \nHorario: 07:00 - 00:11
            \nTrayecto:
            \nDoctor Fedriani (Avda. San Lázaro)
            \nTrabaj. Inmigrantes (Diego de Almagro)
            \nTrabaj. Inmigrantes (Diego Puerta)
            \nTrabaj. Inmigrantes (Los Romeros)
            \nSor Francisca Dorotea (Hdad. Trabajo)
            \nDr. Leal Castaños (Avda. San Lázaro)
            \nSan Juan de Ribera (Policlínico)
            \nMuñoz León (Puerta de Córdoba)
            \nRonda de Capuchinos (San Julián)
            \nRonda de Capuchinos (La Trinidad)
            \nMaría Auxiliadora (Puerta Osario)
            \nRecaredo (San Roque)
            \nMenéndez Pelayo (Puerta Carmona)
            \nMenéndez Pelayo (Puerta de La Carne)
            \nAvenida Carlos V (Prado San Sebastián)
            \nAvenida La Borbolla (Capitanía)
            \nAvenida La Borbolla (Montevideo)
            \nAvenida La Borbolla (Plaza América)
            \nManuel Siurot (Edificio La Estrella)
            \nManuel Siurot (Cardenal Ilundain)
            \nManuel Siurot (Hospital V.Rocio)
            \nManuel Siurot (Francisco Murillo)
            \nManuel Siurot (Carretera Su Eminencia)
            \nCtra. Su Eminencia (Castillo de Marcheni)
            \n¿Puedo ayudarte en algo más?""")
        elif answerclass == "Linea_2":
            print ("""Línea 2. Barqueta Heliopolis
            \nHorario: 06:58 - 00:14
            \nTrayecto:
            \nResolana (Barqueta)
            \nResolana (Feria)
            \nSan Juan de Ribera (Macarena)
            \nSan Juan de Ribera (Policlínico)
            \nDoctor Leal Castaños (Huerta del Carmen)
            \nSor Francisca Dorotea (Bda. La Barzola)
            \nRonda de Pío XII (Madreselva)
            \nAvenida Llanes (Miraflores)
            \nAvenida Llanes (Carretera Carmona)
            \nAlcalde Manuel del Valle (Jose Perez Ocaña)
            \nAlcalde Manuel del Valle (Hespérides)
            \nAlcalde Manuel del Valle (Kansas City)
            \nÉfeso (Avenida Soleá)
            \nAda (Tarso)
            \nAda (Avenida Montes Sierra)
            \nJosé M. Javierre (Los Arcos)
            \nRda. Tamarguillo (Alejandro Collantes)
            \nRda. Tamarguillo (Marqués de Pickman)
            \nRda. Tamarguillo (Francisco Buendía)
            \nRonda del Tamarguillo (Ramón y Cajal)
            \nRda. Tamarguillo (Av. de La Paz)
            \nPoeta Manuel Benítez (Rda. La Oliva)
            \nPoeta Manuel Benítez (P. González Abato)
            \nMarqués Luca de Tena (Virgen del Rocío)
            \nMarqués Luca de Tena (Hospital V.Rocio)
            \nPadre G. Tejero (Est. Benito Villamarín)
            \nGlorieta Alcalde Parias Perry
            \n¿Puedo ayudarte en algo más?""")
        elif answerclass == "Linea_3":
            print ("""Línea 3. Bellavista-S. Jeronimo-Pino Montano
            \nHorario: 06:00 - 00:42
            \nTrayecto:
            \nCtra. Isla Menor (Inst. La Grasa)
            \nAvenida Bellavista (Hospital de Valme)
            \nAvda. Bellavista (Asensio y Toledo)
            \nAvda. Jerez (Jardines de Hércules)
            \nAv. jerez (P.I. Pineda)
            \nAvda. Alemania (Estrasburgo)
            \nPaseo de Europa (Lyon)
            \nDr. Fleming (Est. Benito Villamarín)
            \nReina Mercedes (Gta. Alc. Parias Merry)
            \nReina Mercedes (Escuela de Arquitectura)
            \nLa Palmera (Bueno Monreal)
            \nPaseo las Delicias (Glta. Marineros)
            \nPaseo Colón (Jardines Cristina)
            \nMarques de Paradas
            \nTorneo (Estacion Plaza de Armas)
            \nTorneo (San Lorenzo)
            \nConcejal Jiménez Becerril (Barqueta)
            \nConcejal Jiménez Becerril (José Díaz)
            \nConcej. Jiménez Becerril (Gta. Olímpica)
            \nJosé Galán Merino (Cantina)
            \nJosé Galán Merino (Alcalá del Río)
            \nNavarra (Larache)
            \nCataluña (Parroquia San Jerónimo)
            \nMedina y Galnares (frt. Centro Salud)
            \nBiologia (frente El Higueron)
            \nGta. Oceanografica (Parque Emp. Torneo)
            \nEstrella Canopus
            \nAgricultores (Sembradores)
            \nAgricultores (Garrochistas)
            \n¿Puedo ayudarte en algo más?""")
        elif answerclass == "Linea_5":
            print ("""Línea 5. Puerta Triana - Santa Aurelia
            \nHorario: 05:56 - 00:35
            \nTrayecto:
            \nCamino de Los descubr(Torre Sevilla)
            \nRonda Triana (C.D. Álvarez Gordón)
            \nRonda de Triana (Manuel Arellano)
            \nRonda de Triana (San Vicente de Paúl)
            \nLópez de Gomara (San Martín de Porres)
            \nLópez de Gomara (Instituto Bécquer)
            \nRepública Argentina (Virgen de África)
            \nAvda. República Argentina (Calle Arcos)
            \nRepública Argentina (Plaza de Cuba)
            \nPalos de La Frontera (Teatro Lope de Vega)
            \nMenéndez Pelayo (Juzgados)
            \nMenéndez Pelayo (Diputación)
            \nEduardo Dato (San Bernardo)
            \nEduardo Dato (Colegio Porta Coeli)
            \nEduardo Dato (Estadio Sánchez Pizjuán)
            \nEduardo Dato (San Juan de Dios)
            \nGran Plaza
            \nMarqués de Pickman (Mercado)
            \nConcej. Jiménez Becerril (Gta. Olímpica)
            \nJosé Galán Merino (Cantina)
            \nJosé Galán Merino (Alcalá del Río)
            \nNavarra (Larache)
            \nCataluña (Parroquia San Jerónimo)
            \nMedina y Galnares (frt. Centro Salud)
            \nBiologia (frente El Higueron)
            \nGta. Oceanografica (Parque Emp. Torneo)
            \nEstrella Canopus
            \nAgricultores (Sembradores)
            \nAgricultores (Garrochistas)
            \n¿Puedo ayudarte en algo más?""")
        elif answerclass == "Linea_6":
            print ("""Línea 6. Gta. S. Lázaro - Hosp. V. Rocio
            \nHorario: 06:00 - 00:19
            \nTrayecto:
            \nGlorieta San Lázaro (Romanticismo)
            \nDoctor Fedriani (Ágata)
            \nDoctor Fedriani (Doctor Marañón)
            \nJosé Díaz (Macarena Tres Huertas)
            \nConcejal Jiménez Becerril (José Díaz)
            \nAvda. Jiménez Becerril (F. Odontología)
            \nConcejal Jiménez Becerril (Barqueta)
            \nTorneo (Puerta de San Juan)
            \nTorneo (San Lorenzo)
            \nTorneo (Baños)
            \nTorneo (San Laureano)
            \nCristo de La Expiración (Plaza de Armas)
            \nJimenez de Quesada (Torre Sevilla)
            \nRonda Triana (C.D. Álvarez Gordón)
            \nRonda de Triana (Manuel Arellano)
            \nRonda de Triana (San Vicente de Paúl)
            \nLópez de Gomara (San Martín de Porres)
            \nLópez de Gomara (Instituto Bécquer)
            \nSanta Fe (Niebla)
            \nVirgen de Luján (Virgen del Águila)
            \nVirgen de Luján (Juan Ramón Jiménez)
            \nVirgen de Luján (Sebastián Elcano)
            \nPaseo Las delicias (Pab. de Guatemala)
            \nPaseo Las delicias (Glorieta Méjico)
            \nLa Palmera (Bueno Monreal)
            \nSor Gregoria Santa Teresa
            \nReina Mercedes (Escuela Ing. Edificación)
            \nReina Mercedes (E.S.I. Informática)
            \nReina Mercedes (Glta. Alc. Parias Merry)
            \nPadre G. Tejero (Est. Benito Villamarín)
            \nManuel Siurot (Rafael Salgado)
            \nMarqués Luca de Tena (La Palmera)
            \nPadre G. Tejero (Est. Benito Villamarín)
            \n¿Puedo ayudarte en algo más?""")
        elif answerclass == "Billete_univiaje":
            print ("""Precio: 1,40€
            \nSe adquiere a bordo del autobús o en las máquinas dispensadoras de las paradas del Metrocentro y sirve para un solo viaje.
            \nUna vez adquirido el título de viaje no será reintegrado su importe bajo ningún concepto, ni siquiera en caso de extravío o sustracción del mismo.
            \nLa no utilización del billete no dará derecho a la devolución del importe.
            \n¿Puedo ayudarte en algo más?
            """)
        elif answerclass == "Tarjeta_multiviaje":
            print ("""Tarjeta recargable. Válida para tantos viajes como se desee.
            \nPrecio sin transbordo: 0,69€
            \nPrecio con transbordo: 0,76€
            \nTiene una recarga mínima de 7€ y una máxima de 50€.
            \nAl recargar puedes elegir si la quieres con opción de transbordo o no.
            \nAdquirir esta tarjeta tiene un costo de 1,50€ en concepto de fianza.
            \n¿Puedo ayudarte en algo más?""")
        elif answerclass == "Tarjeta_turistica":
            print ("""Se puede obtener por un período de un día o de 3 días.
            \nEn función de la modalidad seleccionada tiene un costo de 5€ o 10€, respectivamente.
            \nAdquirir la tarjeta tiene un costo de 1,50€ en concepto de fianza.
            \nSe puede adquirir en los Puntos de Atención de Prado San Sebastián, Plaza Ponce de León y en Avda. Andalucía, 11.
            \n¿Puedo ayudarte en algo más?""")
        elif answerclass == "Tarjeta_30_dias":
            print ("""Su uso es válido 30 días naturales sin límite de viajes.
            \nSu precio:
            \nGeneral: 35,30€
            \nFamilia numerosa general: 28,24€
            \nFamilia numerosa especial: 17,65€ 
            \n¿Puedo ayudarte en algo más?""")
        elif answerclass == "Tarjeta_anual":
            print ("""Tarjeta nominativa válida para los 365 días siguientes al primer uso.
            \nSu precio es de 320€ 
            \n¿Puedo ayudarte en algo más?""")
        elif answerclass == "Tarjeta_estudiante":
            print ("""Esta tarjeta tiene validez entre el 1 de septiembre y el 31 de julio del año siguiente.
            \nPuedes pagar 190€ en dos plazos y tenerla activa todos los meses o pagarla mes a mes, con un costo de 19€ cada vez.
            \n¿Puedo ayudarte en algo más?""")
        elif answerclass == "Saludo":
            num = random.random()
            if num < 0.33 :
                print ("Hola :) ¿En qué puedo ayudarte?")
            elif 0.33 <= num < 0.66 :
                print ("Hola. ¿Necesitas ayuda?")
            elif num >= 0.66:
                print ("Hola! Dime en qué puedo ayudarte.")
        elif answerclass == "Ayuda":
            print ("He sido entrenado para darte información sobre las líneas de autobuses de Sevilla y los diferentes titulos/tarjetas disponibles.")
            print ("Puedes probar a preguntarme sobre ellos.")
            print ("Ten en cuenta que no tengo información de todas las lineas ni de todos los títulos, pero lo haré lo mejor que pueda.")
    else:
        print ("Disculpa, no te he entendido bien. Si quieres que te ayude dime \"Necesito ayuda\" ")

# %%
print ("Soy es el Chatbot de ayuda de Tussam, en que puedo ayudarte?")

while True:
    answer_question()
# Out:
# Soy es el Chatbot de ayuda de Tussam, en que puedo ayudarte?
# >Hola
# Hola! Dime en qué puedo ayudarte.
# >que puedes hacer?
# He sido entrenado para darte información sobre las líneas de autobuses de Sevilla y los diferentes titulos/tarjetas disponibles
# Puedes probar a preguntarme sobre ellos
# Ten en cuenta que no tengo información de todas las lineas ni de todos los títulos, pero lo haré lo mejor que pueda
# >Que lineas tienes disponibles
# Actualmente tengo información sobre las lineas 1, 2, 3, 5 y 6.
# Las demás se añadirán en funciones futuras. ¿Sobre cual de ellas quieres información?
# >Dime las paradas de la linea 1
# Línea 1. Plg. Norte H. Virgen del Rocio
#
# Horario: 07:00 - 00:11
#
# Trayecto:
#
# Doctor Fedriani (Avda. San Lázaro)
#
# Trabaj. Inmigrantes (Diego de Almagro)
#
# Trabaj. Inmigrantes (Diego Puerta)
#
# Trabaj. Inmigrantes (Los Romeros)
#
# Sor Francisca Dorotea (Hdad. Trabajo)
#
# Dr. Leal Castaños (Avda. San Lázaro)
#
# San Juan de Ribera (Policlínico)
# ...
