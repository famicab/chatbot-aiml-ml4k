# %%
# %pip install response

# %%
import requests

# This function will pass your text to the machine learning model
# and return the top result with the highest confidence
def classify(text):
    key = "cd419ec0-749d-11ec-9ed4-a70226fed41e14d9ed64-3645-4a5a-843b-88b9307dc2e3"
    url = "https://machinelearningforkids.co.uk/api/scratch/"+ key + "/classify"

    response = requests.get(url, params={ "data" : text })

    if response.ok:
        responseData = response.json()
        topMatch = responseData[0]
        return topMatch
    else:
        response.raise_for_status()

# %%
def get_pattern():
    question = input(">")
    answer = classify(question)
    return answer

# %%
from programy.clients.embed.datafile import EmbeddedDataFileBot

chatbot = EmbeddedDataFileBot(files={'aiml':['files'],
                                    }, defaults=True)

# %%
try:
    while True:
        pattern = get_pattern()
        class_name = pattern["class_name"]
        if pattern["confidence"]>65:
            #class_name = "Ayuda"
            answer = chatbot.ask_question(class_name)
            if (answer.__contains__(",")):
                txt = answer.split(",")
                for i in txt:
                    print(i)
            else:
                print(answer)
            #print(chatbot.ask_question(class_name))
        else:
            print("Disculpa, no te he entendido bien. Si quieres que te ayude dime \"Necesito ayuda\"")
except:
    pass
# Out:
# >lineas
# Actualmente tengo información sobre las lineas 1
# 2
#  3
# 5 y 6. Las demás se
# añadirán en funciones futuras. ¿Sobre cual de ellas quieres información?
# >1
# Línea 1. Plg. Norte H. Virgen del Rocio Horario: 07:00 - 00:11 Trayecto: Doctor
# Fedriani (Avda. San Lázaro)
# Trabaj. Inmigrantes (Diego de Almagro)
# Trabaj.
# Inmigrantes (Diego Puerta)
# Trabaj. Inmigrantes (Los Romeros)
# Sor Francisca
# Dorotea (Hdad. Trabajo)
# Dr. Leal Castaños (Avda. San Lázaro)
# San Juan de Ribera
# (Policlínico)
# Muñoz León (Puerta de Córdoba)
# Ronda de Capuchinos (San
# Julián)
# Ronda de Capuchinos (La Trinidad)
# María Auxiliadora (Puerta
# Osario)
# Recaredo (San Roque)
# Menéndez Pelayo (Puerta Carmona)
# Menéndez Pelayo
# (Puerta de La Carne)
# Avenida Carlos V (Prado San Sebastián)
# Avenida La Borbolla
# (Capitanía)
# Avenida La Borbolla (Montevideo)
# Avenida La Borbolla (Plaza
# América)
# Manuel Siurot (Edificio La Estrella)
# Manuel Siurot (Cardenal
# Ilundain)
# Manuel Siurot (Hospital V.Rocio)
# Manuel Siurot (Francisco
# Murillo)
# Manuel Siurot (Carretera Su Eminencia)
# Ctra. Su Eminencia (Castillo de
# Marcheni)
# ¿Puedo ayudarte en algo más?
# >2
# Línea 2. Barqueta Heliopolis Horario: 06:58 - 00:14 Trayecto: Resolana
# (Barqueta)
# Resolana (Feria)
# San Juan de Ribera (Macarena)
# San Juan de Ribera
# (Policlínico)
# Doctor Leal Castaños (Huerta del Carmen)
# Sor Francisca Dorotea
# (Bda. La Barzola)
# Ronda de Pío XII (Madreselva)
# Avenida Llanes
# (Miraflores)
# Avenida Llanes (Carretera Carmona)
# Alcalde Manuel del Valle (Jose
# Perez Ocaña)
# Alcalde Manuel del Valle (Hespérides)
# Alcalde Manuel del Valle
# (Kansas City)
# Éfeso (Avenida Soleá)
# Ada (Tarso)
# Ada (Avenida Montes Sierra)
# José
# M. Javierre (Los Arcos)
# Rda. Tamarguillo (Alejandro Collantes)
# Rda. Tamarguillo
# (Marqués de Pickman)
# Rda. Tamarguillo (Francisco Buendía)
# Ronda del Tamarguillo
# (Ramón y Cajal)
# Rda. Tamarguillo (Av. de La Paz)
# Poeta Manuel Benítez (Rda. La
# Oliva)
# Poeta Manuel Benítez (P. González Abato)
# Marqués Luca de Tena (Virgen del
# Rocío)
# Marqués Luca de Tena (Hospital V.Rocio)
# Padre G. Tejero (Est. Benito
# Villamarín)
# Glorieta Alcalde Parias Perry
# ¿Puedo ayudarte en algo más?
# >3
# Línea 3. Bellavista-S. Jeronimo-Pino Montano Horario: 06:00 - 00:42 Trayecto:
# Ctra. Isla Menor (Inst. La Grasa)
# Avenida Bellavista (Hospital de Valme)
# Avda.
# Bellavista (Asensio y Toledo)
# Avda. Jerez (Jardines de Hércules)
# Av. jerez (P.I.
# Pineda)
# Avda. Alemania (Estrasburgo)
# Paseo de Europa (Lyon)
# Dr. Fleming (Est.
# Benito Villamarín)
# Reina Mercedes (Gta. Alc. Parias Merry)
# Reina Mercedes
# (Escuela de Arquitectura)
# La Palmera (Bueno Monreal)
# Paseo las Delicias (Glta.
# Marineros)
# Paseo Colón (Jardines Cristina)
# Marques de Paradas
# Torneo (Estacion
# Plaza de Armas)
# Torneo (San Lorenzo)
# Concejal Jiménez Becerril
# (Barqueta)
# Concejal Jiménez Becerril (José Díaz)
# Concej. Jiménez Becerril (Gta.
# Olímpica)
# José Galán Merino (Cantina)
# José Galán Merino (Alcalá del Río)
# Navarra
# (Larache)
# Cataluña (Parroquia San Jerónimo)
# Medina y Galnares (frt. Centro
# Salud)
# Biologia (frente El Higueron)
# Gta. Oceanografica (Parque Emp.
# Torneo)
# Estrella Canopus
# Agricultores (Sembradores)
# Agricultores
# (Garrochistas)
# ¿Puedo ayudarte en algo más?
